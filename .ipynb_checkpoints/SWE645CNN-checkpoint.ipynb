# %% [markdown]
# # Traffic Sign Classification with Convolutional Neural Networks by TensorFlow

# %% [markdown]
# This is a George Mason University SWE 645 course project.<br>
# Topic: Traffic Sign Classification with Convolutional Neural Networks by TensorFlow<br>
# Reference research: Sermanet, P. and LeCun, Y. Traffic Sign Recognition with Multi-Scale Convolutional Networks
#     yann.lecun.com/exdb/publis/pdf/sermanet-ijcnn-11.pdf<br>
# Dataset: German Traffic Sign Benchmark<br>
#     http://benchmark.ini.rub.de/?section=gtsrb&subsection=dataset<br>
#     https://www.kaggle.com/meowmeowmeowmeowmeow/gtsrb-german-traffic-sign<br>
# Object: In the research paper, it states several Convolutional Neural Network models to do the recognition and classification for German Traffic Sign. It uses a C++ package and Matlab to implement. The highest accuracy is above 99%. So now I would like to implement a CNN model by using TensorFlow and OpenCV to achieve at least 95% accuracy.

# %% [markdown]
# For test convenient, I didn't run the preprocess image part in Jupyter Notebook because it will generate a large amount of files and doesn't show up message on command console. The Jupyter running part is begining at Result of Pre-process. If you want to test the preprocess functions, please see preprocess.py in my source code.

# %% [markdown]
# # 1. Preprocess the data image
# According to Pierre Sermanet and Yann LeCun, color image actually doesn't help a lot. So I choose only work on gray image. The preprocess steps include: crop and resize the image to 48x48, transfer color image into gray, smooth the image by Gaussian Blur, equalize the image histogram, and finally normalize it.

# %%
import os
import cv2
import numpy as np
import shutil
import pandas as pd
import PIL.Image as Image

# %% [markdown]
# Define crop and resize image function. In this function, current .csv file would be read, and we get image file path, ROI region, and class id. We process the image and then save new images to a new file path with a new .csv file.

# %%
def crop_and_resize_image(csv_file_from_path, csv_file_to_path, dir_to_path, width, height):
    # if cvs_file_path does exist, throw exception
    if not os.path.exists(csv_file_from_path):
        raise ImportError

    # if dir_to_path does not exist, then create one; if exist, remove and recreate
    if not os.path.exists(dir_to_path):
        os.makedirs(dir_to_path)
    else:
        shutil.rmtree(dir_to_path)
        os.makedirs(dir_to_path)

    # read csv file
    print("Using: " + csv_file_from_path)
    annotations = pd.read_csv(csv_file_from_path, header=0)
    index = annotations.index.tolist()
    annotations = annotations.set_index([index])
    print(annotations)

    # record new file path and class save to new .csv file
    new_file_name_collection = []
    new_class_name_collection = []

    # iterate the image listed in .csv file
    for i in range(len(annotations)):
        # read image path and make new path
        image_file_path = annotations.at[i, 'Path']
        image_file_path = "./" + image_file_path
        image_new_file_path = os.path.join(dir_to_path, image_file_path.split('/')[-1])
        print("Current processing: " + image_new_file_path)

        # read ROI region
        x1 = annotations.at[i, 'Roi.X1']
        y1 = annotations.at[i, 'Roi.Y1']
        x2 = annotations.at[i, 'Roi.X2']
        y2 = annotations.at[i, 'Roi.Y2']

        # crop and resize region
        image = Image.open(image_file_path)
        image = image.crop((x1, y1, x2, y2))
        image = image.resize((width, height), resample=Image.BILINEAR)
        image.save(image_new_file_path)

        # equalize and normalize image
        image = cv2.imread(image_new_file_path)
        gray_img = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
        cv2.imwrite(image_new_file_path, gray_img)
        equalize_normalize_images(image_new_file_path, width, height)

        # record class id
        classId = annotations.at[i, 'ClassId']
        new_file_name_collection.append(image_new_file_path)
        new_class_name_collection.append(classId)

    # save new image file path and new class id to new .csv file
    df = pd.DataFrame({'file': new_file_name_collection,
                       'class': new_class_name_collection})
    df.to_csv(path_or_buf=csv_file_to_path, index=False)

# %%
def equalize_normalize_images(image_path, width, height):
    image = cv2.imread(image_path, 0)

    # Gaussian filtering
    blur_img = cv2.GaussianBlur(image, (5, 5), 0)

    # equalize the histogram
    equalized_img = cv2.equalizeHist(blur_img)

    # normalize the image
    normalized_img = np.zeros((width, height))
    normalized_img = cv2.normalize(equalized_img, normalized_img, 0, 255, cv2.NORM_MINMAX)

    cv2.imwrite(image_path, normalized_img)

# %% [markdown]
# ## Extend the preprocessed data image<br>
# In reality, the captured traffic sign might be scaled or rotated in a different way. In order to recognize those images, we can randomly perturbe the preprocessed image in position ([-2,2] pixels), in scale ([.9,1.1] ratio) and rotation ([-10,+10] degrees).

# %% [markdown]
# Import random to generate number number

# %%
import random
import time

# %%
def crop_and_resize_image_extend(csv_file_from_path, csv_file_to_path, dir_to_path, width, height):
    # if cvs_file_path does exist, throw exception
    if not os.path.exists(csv_file_from_path):
        raise ImportError

    # if dir_to_path does not exist, then create one; if exist, remove and recreate
    if not os.path.exists(dir_to_path):
        os.makedirs(dir_to_path)
    else:
        shutil.rmtree(dir_to_path)
        os.makedirs(dir_to_path)

    # read csv file
    print("Using: " + csv_file_from_path)
    annotations = pd.read_csv(csv_file_from_path, header=0)
    index = annotations.index.tolist()
    annotations = annotations.set_index([index])
    print(annotations)

    # record new file path and class save to new .csv file
    new_file_name_collection = []
    new_class_name_collection = []

    # iterate the image listed in .csv file
    for i in range(len(annotations)):
        # read image path and make new path
        image_file_path = annotations.at[i, 'Path']
        image_sub_file_path = image_file_path.split('/')[-1]
        image_name = image_sub_file_path.split('.')[0]
        image_new_name_1 = image_name + "_01.png"
        image_new_name_2 = image_name + "_02.png"
        image_new_name_3 = image_name + "_03.png"
        image_new_file_path_1 = os.path.join(dir_to_path, image_new_name_1)
        image_new_file_path_2 = os.path.join(dir_to_path, image_new_name_2)
        image_new_file_path_3 = os.path.join(dir_to_path, image_new_name_3)

        # read ROI region
        x1 = annotations.at[i, 'Roi.X1']
        y1 = annotations.at[i, 'Roi.Y1']
        x2 = annotations.at[i, 'Roi.X2']
        y2 = annotations.at[i, 'Roi.Y2']

        # crop and resize region
        random_shift(image_file_path, image_new_file_path_1, width, height, x1, y1, x2, y2)
        random_scale(image_file_path, image_new_file_path_2, width, height, x1, y1, x2, y2)
        random_rotate(image_file_path, image_new_file_path_3, width, height, x1, y1, x2, y2)

        # equalize and normalize image
        equalize_normalize_images(image_new_file_path_1, width, height)
        equalize_normalize_images(image_new_file_path_2, width, height)
        equalize_normalize_images(image_new_file_path_3, width, height)

        # record class id
        classId = annotations.at[i, 'ClassId']
        new_file_name_collection.append(image_new_file_path_1)
        new_class_name_collection.append(classId)
        new_file_name_collection.append(image_new_file_path_2)
        new_class_name_collection.append(classId)
        new_file_name_collection.append(image_new_file_path_3)
        new_class_name_collection.append(classId)

    # save new image file path and new class id to new .csv file
    df = pd.DataFrame({'file': new_file_name_collection,
                       'class': new_class_name_collection})
    df.to_csv(path_or_buf=csv_file_to_path, index=False)

# %%
def random_rotate(image_file_path, image_new_file_path, width, height, x1, y1, x2, y2):
    # set current time to random seed
    random.seed(time.time())

    # generate random parameters
    delta_rotation = random.randint(-10, 11)

    img = cv2.imread(image_file_path)
    image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    M = cv2.getRotationMatrix2D((width / 2, height / 2), delta_rotation, 1.0)
    rotated_img = cv2.warpAffine(image, M, (width, height))
    rotated_img_height, rotated_img_width = rotated_img.shape

    i = 0
    while not (0 <= x1 <= rotated_img_width and 0 <= x2 <= rotated_img_width and \
               0 <= y1 <= rotated_img_height and 0 <= y2 <= rotated_img_height):
        delta_rotation = random.randint(-10, 11)
        M = cv2.getRotationMatrix2D((width / 2, height / 2), delta_rotation, 1.0)
        rotated_img = cv2.warpAffine(image, M, (width, height))
        rotated_img_height, rotated_img_width = rotated_img.shape

        # avoid infinite loop
        i += 1
        if i > 100:
            cropped_img = img[y1: y2][x1: x2]
            resized_img = cv2.resize(cropped_img, (width, height))
            cv2.imwrite(image_new_file_path, resized_img)
            return

    cropped_img = rotated_img[y1: y2][x1: x2]
    resized_img = cv2.resize(cropped_img, (width, height))
    cv2.imwrite(image_new_file_path, resized_img)


def random_shift(image_file_path, image_new_file_path, width, height, x1, y1, x2, y2):
    # set current time to random seed
    random.seed(time.time())

    # generate random parameters
    delta_x = random.randint(-2, 3)
    delta_y = random.randint(-2, 3)

    img = cv2.imread(image_file_path)
    image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    image_height, image_width = image.shape

    i = 0
    while not (0 <= x1 + delta_x <= image_width and 0 <= x2 + delta_x <= image_width and \
               0 <= y1 + delta_y <= image_height and 0 <= y2 + delta_y <= image_height):
        delta_x = random.randint(-2, 3)
        delta_y = random.randint(-2, 3)

        # avoid infinite loop
        i += 1
        if i > 100:
            cropped_img = img[y1: y2][x1: x2]
            resized_img = cv2.resize(cropped_img, (width, height))
            cv2.imwrite(image_new_file_path, resized_img)
            return

    new_x1 = x1 + delta_x
    new_y1 = y1 + delta_y
    new_x2 = x2 + delta_x
    new_y2 = y2 + delta_y

    cropped_img = image[new_y1: new_y2][new_x1: new_x2]
    resized_img = cv2.resize(cropped_img, (width, height))
    cv2.imwrite(image_new_file_path, resized_img)


def random_scale(image_file_path, image_new_file_path, width, height, x1, y1, x2, y2):
    # set current time to random seed
    random.seed(time.time())

    # generate random parameters
    delta_scale = random.uniform(0.9, 1.1)

    img = cv2.imread(image_file_path)
    image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    scaled_img = cv2.resize(image, (0, 0), fx=delta_scale, fy=delta_scale)
    scaled_img_height, scaled_img_width = scaled_img.shape

    i = 0
    while not (0 <= x1 <= scaled_img_width and 0 <= x2 <= scaled_img_width and \
               0 <= y1 <= scaled_img_height and 0 <= y2 <= scaled_img_height):
        delta_scale = random.uniform(0.9, 1.1)
        scaled_img = cv2.resize(image, (0, 0), fx=delta_scale, fy=delta_scale)
        scaled_img_height, scaled_img_width = scaled_img.shape

        # avoid infinite loop
        i += 1
        if i > 100:
            cropped_img = img[y1: y2][x1: x2]
            resized_img = cv2.resize(cropped_img, (width, height))
            cv2.imwrite(image_new_file_path, resized_img)
            return

    cropped_img = scaled_img[y1: y2][x1: x2]
    resized_img = cv2.resize(cropped_img, (width, height))
    cv2.imwrite(image_new_file_path, resized_img)

# %%
def do_preprocess():
    print("Preprocess begin...")
    crop_and_resize_image('./Train.csv', './Train_processed.csv', './Train_processed', 48, 48)
    crop_and_resize_image_extend('./Train.csv', './Train_processed_extend.csv', './Train_processed_extend', 48, 48)
    print("End of preprocess.")

# %% [markdown]
# # Important Notice:

# %% [markdown]
# Calling the following do_preprocess() function is optional. Since the project has already done the processing, you can skip this step. But if you do want to test it, please allow some time to process.

# %%
do_preprocess()
# Out:
# Preprocess begin...
# Using: ./Train.csv
#        Width  Height  Roi.X1  Roi.Y1  Roi.X2  Roi.Y2  ClassId  \
# 0         27      26       5       5      22      20       20
# 1         28      27       5       6      23      22       20
# 2         29      26       6       5      24      21       20
# 3         28      27       5       6      23      22       20
# 4         28      26       5       5      23      21       20
# 5         31      27       6       5      26      22       20
# 6         31      28       6       6      26      23       20
# 7         31      28       6       6      26      23       20
# 8         31      29       5       6      26      24       20
# 9         34      32       6       6      29      26       20
# 10        36      33       5       6      31      28       20
# 11        37      34       5       6      32      29       20
# 12        38      34       5       6      32      29       20
# 13        40      34       6       6      34      29       20
# 14        39      34       5       5      34      29       20
# 15        42      36       6       5      37      31       20
# 16        45      39       6       5      40      34       20
# 17        47      42       5       5      41      36       20
# 18        50      45       5       5      45      40       20
# 19        55      49       6       5      49      43       20
# 20        56      51       6       6      51      46       20
# 21        59      54       5       5      54      49       20
# 22        64      57       6       5      59      52       20
# 23        70      61       6       5      64      56       20
# 24        76      69       6       6      70      63       20
# 25        86      75       8       6      79      69       20
# 26        97      87       8       7      89      80       20
# 27       111     100       9       8     102      92       20
# 28       131     119      12      11     120     109       20
# 29       166     152      15      14     152     139       20
# ...      ...     ...     ...     ...     ...     ...      ...
# 39179     27      28       5       6      22      23       42
# 39180     28      27       6       5      23      22       42
# 39181     28      29       5       5      23      24       42
# 39182     31      31       6       5      26      26       42
# 39183     30      32       5       6      25      27       42
# 39184     30      32       5       6      25      27       42
# 39185     31      31       6       5      26      26       42
# 39186     30      32       5       6      25      27       42
# 39187     30      32       5       6      25      27       42
# 39188     32      32       6       5      27      27       42
# 39189     32      32       6       5      27      27       42
# 39190     33      34       6       6      28      29       42
# 39191     32      34       5       6      27      29       42
# 39192     34      36       5       6      29      31       42
# 39193     34      35       5       5      29      30       42
# 39194     36      37       5       5      31      32       42
# 39195     38      38       6       5      33      33       42
# 39196     38      40       5       6      33      35       42
# 39197     39      40       5       5      34      35       42
# 39198     41      41       6       5      36      36       42
# 39199     44      46       6       6      39      41       42
# 39200     44      46       5       5      39      41       42
# 39201     47      50       5       6      42      45       42
# 39202     49      50       6       5      44      45       42
# 39203     51      53       6       5      46      48       42
# Current processing: ./Train_processed/00020_00010_00011.png
# Current processing: ./Train_processed/00020_00010_00012.png
# Current processing: ./Train_processed/00020_00010_00013.png
# Current processing: ./Train_processed/00020_00010_00014.png
# Current processing: ./Train_processed/00020_00010_00015.png
# Current processing: ./Train_processed/00020_00010_00016.png
# Current processing: ./Train_processed/00020_00010_00017.png
# Current processing: ./Train_processed/00020_00010_00018.png
# Current processing: ./Train_processed/00020_00010_00019.png
# Current processing: ./Train_processed/00020_00010_00020.png
# Current processing: ./Train_processed/00020_00010_00021.png
# Current processing: ./Train_processed/00020_00010_00022.png
# Current processing: ./Train_processed/00020_00010_00023.png
# Current processing: ./Train_processed/00020_00010_00024.png
# Current processing: ./Train_processed/00020_00010_00025.png
# Current processing: ./Train_processed/00020_00010_00026.png
# Current processing: ./Train_processed/00020_00010_00027.png
# Current processing: ./Train_processed/00020_00010_00028.png
# Current processing: ./Train_processed/00020_00010_00029.png
# Current processing: ./Train_processed/00020_00011_00000.png
# Current processing: ./Train_processed/00020_00011_00001.png
# Current processing: ./Train_processed/00020_00011_00002.png
# Current processing: ./Train_processed/00020_00011_00003.png
# Current processing: ./Train_processed/00020_00011_00004.png
# Current processing: ./Train_processed/00020_00011_00005.png
# Current processing: ./Train_processed/00020_00011_00006.png
# Current processing: ./Train_processed/00020_00011_00007.png
# Current processing: ./Train_processed/00020_00011_00008.png
# Current processing: ./Train_processed/00020_00011_00009.png
# Current processing: ./Train_processed/00020_00011_00010.png
# Current processing: ./Train_processed/00020_00011_00011.png
# Current processing: ./Train_processed/00020_00011_00012.png
# Current processing: ./Train_processed/00020_00011_00013.png
# Current processing: ./Train_processed/00020_00011_00014.png
# Current processing: ./Train_processed/00020_00011_00015.png
# Current processing: ./Train_processed/00020_00011_00016.png
# Current processing: ./Train_processed/00020_00011_00017.png
# Current processing: ./Train_processed/00020_00011_00018.png
# Current processing: ./Train_processed/00020_00011_00019.png
# Current processing: ./Train_processed/00020_00011_00020.png
# Current processing: ./Train_processed/00020_00011_00021.png
# Current processing: ./Train_processed/00020_00011_00022.png
# Current processing: ./Train_processed/00020_00011_00023.png
# Current processing: ./Train_processed/00020_00011_00024.png
# Current processing: ./Train_processed/00020_00011_00025.png
# Current processing: ./Train_processed/00020_00011_00026.png
# Current processing: ./Train_processed/00020_00011_00027.png
# Current processing: ./Train_processed/00020_00011_00028.png
# Current processing: ./Train_processed/00020_00011_00029.png
# Current processing: ./Train_processed/00000_00000_00000.png
# Current processing: ./Train_processed/00000_00000_00001.png
# Current processing: ./Train_processed/00000_00000_00002.png
# Current processing: ./Train_processed/00000_00000_00003.png
# Current processing: ./Train_processed/00000_00000_00004.png
# Current processing: ./Train_processed/00000_00000_00005.png
# Current processing: ./Train_processed/00000_00000_00006.png
# Current processing: ./Train_processed/00000_00000_00007.png
# Current processing: ./Train_processed/00000_00000_00008.png
# Current processing: ./Train_processed/00000_00000_00009.png
# Current processing: ./Train_processed/00000_00000_00010.png
# Current processing: ./Train_processed/00042_00006_00010.png
# Current processing: ./Train_processed/00042_00006_00011.png
# Current processing: ./Train_processed/00042_00006_00012.png
# Current processing: ./Train_processed/00042_00006_00013.png
# Current processing: ./Train_processed/00042_00006_00014.png
# Current processing: ./Train_processed/00042_00006_00015.png
# Current processing: ./Train_processed/00042_00006_00016.png
# Current processing: ./Train_processed/00042_00006_00017.png
# Current processing: ./Train_processed/00042_00006_00018.png
# Current processing: ./Train_processed/00042_00006_00019.png
# Current processing: ./Train_processed/00042_00006_00020.png
# Current processing: ./Train_processed/00042_00006_00021.png
# Current processing: ./Train_processed/00042_00006_00022.png
# Current processing: ./Train_processed/00042_00006_00023.png
# Current processing: ./Train_processed/00042_00006_00024.png
# Current processing: ./Train_processed/00042_00006_00025.png
# Current processing: ./Train_processed/00042_00006_00026.png
# Current processing: ./Train_processed/00042_00006_00027.png
# Current processing: ./Train_processed/00042_00006_00028.png
# Current processing: ./Train_processed/00042_00006_00029.png
# Current processing: ./Train_processed/00042_00007_00000.png
# Current processing: ./Train_processed/00042_00007_00001.png
# Current processing: ./Train_processed/00042_00007_00002.png
# Current processing: ./Train_processed/00042_00007_00003.png
# Current processing: ./Train_processed/00042_00007_00004.png
# Current processing: ./Train_processed/00042_00007_00005.png
# Current processing: ./Train_processed/00042_00007_00006.png
# Current processing: ./Train_processed/00042_00007_00007.png
# Current processing: ./Train_processed/00042_00007_00008.png
# Current processing: ./Train_processed/00042_00007_00009.png
# Current processing: ./Train_processed/00042_00007_00010.png
# Current processing: ./Train_processed/00042_00007_00011.png
# Current processing: ./Train_processed/00042_00007_00012.png
# Current processing: ./Train_processed/00042_00007_00013.png
# Current processing: ./Train_processed/00042_00007_00014.png
# Current processing: ./Train_processed/00042_00007_00015.png
# Current processing: ./Train_processed/00042_00007_00016.png
# Current processing: ./Train_processed/00042_00007_00017.png
# Current processing: ./Train_processed/00042_00007_00018.png
# Current processing: ./Train_processed/00042_00007_00019.png
# Current processing: ./Train_processed/00042_00007_00020.png
# Current processing: ./Train_processed/00042_00007_00021.png
# Current processing: ./Train_processed/00042_00007_00022.png
# Current processing: ./Train_processed/00042_00007_00023.png
# Current processing: ./Train_processed/00042_00007_00024.png
# Current processing: ./Train_processed/00042_00007_00025.png
# Current processing: ./Train_processed/00042_00007_00026.png
# Current processing: ./Train_processed/00042_00007_00027.png
# Current processing: ./Train_processed/00042_00007_00028.png
# Current processing: ./Train_processed/00042_00007_00029.png
# Using: ./Train.csv
#        Width  Height  Roi.X1  Roi.Y1  Roi.X2  Roi.Y2  ClassId  \
# 0         27      26       5       5      22      20       20
# 1         28      27       5       6      23      22       20
# 2         29      26       6       5      24      21       20
# 3         28      27       5       6      23      22       20
# 4         28      26       5       5      23      21       20
# 5         31      27       6       5      26      22       20
# 6         31      28       6       6      26      23       20
# 7         31      28       6       6      26      23       20
# 8         31      29       5       6      26      24       20
# 9         34      32       6       6      29      26       20
# 10        36      33       5       6      31      28       20
# 11        37      34       5       6      32      29       20
# 12        38      34       5       6      32      29       20
# 13        40      34       6       6      34      29       20
# 14        39      34       5       5      34      29       20
# 15        42      36       6       5      37      31       20
# 16        45      39       6       5      40      34       20
# 17        47      42       5       5      41      36       20
# 18        50      45       5       5      45      40       20
# 19        55      49       6       5      49      43       20
# 20        56      51       6       6      51      46       20
# 21        59      54       5       5      54      49       20
# 22        64      57       6       5      59      52       20
# 23        70      61       6       5      64      56       20
# 24        76      69       6       6      70      63       20
# 25        86      75       8       6      79      69       20
# 26        97      87       8       7      89      80       20
# 27       111     100       9       8     102      92       20
# 28       131     119      12      11     120     109       20
# 29       166     152      15      14     152     139       20
# ...      ...     ...     ...     ...     ...     ...      ...
# 39179     27      28       5       6      22      23       42
# 39180     28      27       6       5      23      22       42
# 39181     28      29       5       5      23      24       42
# 39182     31      31       6       5      26      26       42
# 39183     30      32       5       6      25      27       42
# 39184     30      32       5       6      25      27       42
# 39185     31      31       6       5      26      26       42
# 39186     30      32       5       6      25      27       42
# 39187     30      32       5       6      25      27       42
# 39188     32      32       6       5      27      27       42
# 39189     32      32       6       5      27      27       42
# 39190     33      34       6       6      28      29       42
# 39191     32      34       5       6      27      29       42
# 39192     34      36       5       6      29      31       42
# 39193     34      35       5       5      29      30       42
# 39194     36      37       5       5      31      32       42
# 39195     38      38       6       5      33      33       42
# 39196     38      40       5       6      33      35       42
# 39197     39      40       5       5      34      35       42
# 39198     41      41       6       5      36      36       42
# 39199     44      46       6       6      39      41       42
# 39200     44      46       5       5      39      41       42
# 39201     47      50       5       6      42      45       42
# 39202     49      50       6       5      44      45       42
# 39203     51      53       6       5      46      48       42
# 39204     52      56       5       6      47      51       42
# 39205     56      58       5       5      51      53       42
# 39206     58      62       5       6      53      57       42
# 39207     63      69       5       7      58      63       42
# 39208     68      69       7       6      62      63       42
#
#                                  Path
# 0      Train/20/00020_00000_00000.png
# 1      Train/20/00020_00000_00001.png
# 2      Train/20/00020_00000_00002.png
# 3      Train/20/00020_00000_00003.png
# 4      Train/20/00020_00000_00004.png
# 5      Train/20/00020_00000_00005.png
# 6      Train/20/00020_00000_00006.png
# 7      Train/20/00020_00000_00007.png
# 8      Train/20/00020_00000_00008.png
# 9      Train/20/00020_00000_00009.png
# 10     Train/20/00020_00000_00010.png
# 11     Train/20/00020_00000_00011.png
# 12     Train/20/00020_00000_00012.png
# 13     Train/20/00020_00000_00013.png
# 14     Train/20/00020_00000_00014.png
# 15     Train/20/00020_00000_00015.png
# 16     Train/20/00020_00000_00016.png
# 17     Train/20/00020_00000_00017.png
# 18     Train/20/00020_00000_00018.png
# 19     Train/20/00020_00000_00019.png
# 20     Train/20/00020_00000_00020.png
# 21     Train/20/00020_00000_00021.png
# 22     Train/20/00020_00000_00022.png
# 23     Train/20/00020_00000_00023.png
# 24     Train/20/00020_00000_00024.png
# 25     Train/20/00020_00000_00025.png
# 26     Train/20/00020_00000_00026.png
# 27     Train/20/00020_00000_00027.png
# 28     Train/20/00020_00000_00028.png
# 29     Train/20/00020_00000_00029.png
# ...                               ...
# 39179  Train/42/00042_00007_00000.png
# 39180  Train/42/00042_00007_00001.png
# 39181  Train/42/00042_00007_00002.png
# 39182  Train/42/00042_00007_00003.png
# 39183  Train/42/00042_00007_00004.png
# 39184  Train/42/00042_00007_00005.png
# 39185  Train/42/00042_00007_00006.png
# 39186  Train/42/00042_00007_00007.png
# 39187  Train/42/00042_00007_00008.png
# 39188  Train/42/00042_00007_00009.png
# 39189  Train/42/00042_00007_00010.png
# 39190  Train/42/00042_00007_00011.png
# 39191  Train/42/00042_00007_00012.png
# 39192  Train/42/00042_00007_00013.png
# 39193  Train/42/00042_00007_00014.png
# 39194  Train/42/00042_00007_00015.png
# 39195  Train/42/00042_00007_00016.png
# 39196  Train/42/00042_00007_00017.png
# 39197  Train/42/00042_00007_00018.png
# 39198  Train/42/00042_00007_00019.png
# 39199  Train/42/00042_00007_00020.png
# 39200  Train/42/00042_00007_00021.png
# 39201  Train/42/00042_00007_00022.png
# 39202  Train/42/00042_00007_00023.png
# 39203  Train/42/00042_00007_00024.png
# 39204  Train/42/00042_00007_00025.png
# 39205  Train/42/00042_00007_00026.png
# 39206  Train/42/00042_00007_00027.png
# 39207  Train/42/00042_00007_00028.png
# 39208  Train/42/00042_00007_00029.png
#
# [39209 rows x 8 columns]
# End of preprocess.

# %% [markdown]
# # Result of Pre-process

# %%
import matplotlib.pyplot as plt
from PIL import Image
import os


def plot_images(file_path, row, col):
    fig = plt.figure(figsize=(8, 8))
    i = 1
    for image_name in os.listdir(file_path):
        if i >= row*col + 1:
            break
        if image_name.endswith('.png'):
            img = Image.open(os.path.join(file_path, image_name))
            fig.add_subplot(row, col, i)
            plt.imshow(img)
            i += 1
    plt.show()

# %%
plot_images('./Train/0', 4, 5)
plot_images('./Train_processed', 4, 5)
plot_images('./Train_processed_extend', 4, 5)

# %% [markdown]
# # 2. Build trainning model

# %% [markdown]
# According to the research, # 178 -- 2 layers ConvNet with 108 features and 108 features could reach 98.97% accuracy. However, limited by my machine's computing ability, I choose to mock # 26 -- 2 layers ConvNet with 38 features and 64 features, which theoretically could reach 98.89% accuracy. However, I'm going to add another layer. So my model would be 3 layers ConvNet with 16 features, 32 features, and 64 features.

# %% [markdown]
# First to build read data function

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from PIL import Image

# %%
def read_data(csv_file_path):
    # open .csv file
    annotations = pd.read_csv(csv_file_path)
    rows, cols = annotations.shape

    image_path_collection = []
    image_class_collection = []

    # read data in row
    for i in range(rows):
        image_path = annotations.at[i, 'file']
        image_class = annotations.at[i, 'class']
        image_path_collection.append(image_path)
        class_array = np.zeros(43)
        class_array[int(image_class)] = 1
        image_class_collection.append(class_array)

    print("Input image size: " + str(len(image_path_collection)))
    print("Input label size: " + str(len(image_class_collection)))

    # load image in memory
    image_collection = []
    for i in range(len(image_path_collection)):
        image = Image.open(image_path_collection[i])
        image_array = np.array(image)
        image_collection.append(image_array)

    if len(image_collection) == len(image_class_collection):
        return np.array(image_collection), np.array(image_class_collection)
    else:
        raise ImportError

# %% [markdown]
# Then define the trainning model

# %%
def init_train():
    
    num_classes = 43
    input_shape = (48, 48, 1)
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(filters=16, kernel_size=5, strides=1,
                               padding='same', activation='relu', input_shape=input_shape),
        tf.keras.layers.MaxPool2D(pool_size=2, strides=2),
        tf.keras.layers.Dropout(0.1),
        tf.keras.layers.Conv2D(filters=32, kernel_size=5, strides=1,
                               padding='same', activation='relu'),
        tf.keras.layers.MaxPool2D(pool_size=2, strides=2),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Conv2D(filters=64, kernel_size=5, strides=1,
                               padding='same', activation='relu'),
        tf.keras.layers.MaxPool2D(pool_size=2, strides=2),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(num_classes, activation='softmax')
    ])

    model.compile(optimizer='adam', loss=tf.keras.losses.categorical_crossentropy, metrics=['accuracy'])

    # import data
    train_xs, train_ys = read_data('./Train_processed.csv')
    test_xs, test_ys = read_data('./Test_processed.csv')
    train_xs = np.expand_dims(train_xs, axis=3)
    test_xs = np.expand_dims(test_xs, axis=3)

    # run model
    model.fit(train_xs, train_ys, batch_size=500, epochs=10, verbose=1)
    loss, acc = model.evaluate(test_xs, test_ys)
    print("\n\n==============================================================\n\n")
    print("Loss {}, Accuracy {}".format(loss, acc))
    print("\n\n==============================================================\n\n")

init_train()
# Out:
# Input image size: 39209
# Input label size: 39209
# Input image size: 12630
# Input label size: 12630
# Epoch 1/10
# 39209/39209 [==============================] - 45s 1ms/sample - loss: 6.0164 - accuracy: 0.1193
# Epoch 2/10
# 39209/39209 [==============================] - 39s 1ms/sample - loss: 1.6283 - accuracy: 0.5201
# Epoch 3/10
# 39209/39209 [==============================] - 36s 914us/sample - loss: 0.5442 - accuracy: 0.8293
# Epoch 4/10
# 39209/39209 [==============================] - 37s 942us/sample - loss: 0.2880 - accuracy: 0.9066
# Epoch 5/10
# 39209/39209 [==============================] - 45s 1ms/sample - loss: 0.2040 - accuracy: 0.9328
# Epoch 6/10
# 39209/39209 [==============================] - 40s 1ms/sample - loss: 0.1576 - accuracy: 0.9495
# Epoch 7/10
# 39209/39209 [==============================] - 41s 1ms/sample - loss: 0.1277 - accuracy: 0.9587
# Epoch 8/10
# 39209/39209 [==============================] - 42s 1ms/sample - loss: 0.1117 - accuracy: 0.9647
# Epoch 9/10
# 39209/39209 [==============================] - 40s 1ms/sample - loss: 0.0970 - accuracy: 0.9685
# Epoch 10/10
# 39209/39209 [==============================] - 40s 1ms/sample - loss: 0.0811 - accuracy: 0.9742
# 12630/12630 [==============================] - 5s 427us/sample - loss: 0.1321 - accuracy: 0.9610
#
#
# ==============================================================
#
#
# Loss 0.13209108036905173, Accuracy 0.9609659314155579
#
#
# ==============================================================

# %% [markdown]
# # Output Comments

# %% [markdown]
# As we can see, with 39209 train image and 12630 test image input, the model could reach 97% accuracy within 10 epochs with BATCH_SIZE = 500, which is a really great result. Actually for training dataset, the model has already reach 99%. So, we can see there is some features that the non-extend dataset doesn't cover. Let's add the extend image data to see what will happen.

# %% [markdown]
# # 3. Continue train with extend image data

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from PIL import Image

def read_data_array(csv_file_paths):
    image_path_collection = []
    image_class_collection = []

    for csv_file_path in csv_file_paths:
        annotations = pd.read_csv(csv_file_path)
        rows, cols = annotations.shape

        for i in range(rows):
            image_path = annotations.at[i, 'file']
            image_class = annotations.at[i, 'class']
            image_path_collection.append(image_path)
            class_array = np.zeros(43)
            class_array[int(image_class)] = 1
            image_class_collection.append(class_array)

    print("Input image size: " + str(len(image_path_collection)))
    print("Input label size: " + str(len(image_class_collection)))

    image_collection = []
    for i in range(len(image_path_collection)):
        image = Image.open(image_path_collection[i])
        image_array = np.array(image)
        image_collection.append(image_array)

    if len(image_collection) == len(image_class_collection):
        return np.array(image_collection), np.array(image_class_collection)
    else:
        raise ImportError


def continue_train():

    num_classes = 43
    input_shape = (48, 48, 1)
    model = tf.keras.Sequential([
        tf.keras.layers.Conv2D(filters=16, kernel_size=5, strides=1,
                               padding='same', activation='relu', input_shape=input_shape),
        tf.keras.layers.MaxPool2D(pool_size=2, strides=2),
        tf.keras.layers.Dropout(0.1),
        tf.keras.layers.Conv2D(filters=32, kernel_size=5, strides=1,
                               padding='same', activation='relu'),
        tf.keras.layers.MaxPool2D(pool_size=2, strides=2),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Conv2D(filters=64, kernel_size=5, strides=1,
                               padding='same', activation='relu'),
        tf.keras.layers.MaxPool2D(pool_size=2, strides=2),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(num_classes, activation='softmax')
    ])

    model.compile(optimizer=tf.keras.optimizers.Nadam(lr=0.0002, schedule_decay=1e-4), 
                  loss=tf.keras.losses.categorical_crossentropy, metrics=['accuracy'])

    # import data
    train_xs, train_ys = read_data_array(['./Train_processed.csv', './Train_processed_extend.csv'])
    test_xs, test_ys = read_data_array(['./Test_processed.csv'])
    train_xs = np.expand_dims(train_xs, axis=3)
    test_xs = np.expand_dims(test_xs, axis=3)

    # run model
    model.fit(train_xs, train_ys, batch_size=500, epochs=10, verbose=1)
    loss, acc = model.evaluate(test_xs, test_ys)
    print("\n\n==============================================================\n\n")
    print("Loss {}, Accuracy {}".format(loss, acc))
    print("\n\n==============================================================\n\n")


continue_train()
# Out:
# Input image size: 156836
# Input label size: 156836
# Input image size: 12630
# Input label size: 12630
# Epoch 1/10
# 156836/156836 [==============================] - 171s 1ms/sample - loss: 5.6877 - accuracy: 0.1026
# Epoch 2/10
# 156836/156836 [==============================] - 169s 1ms/sample - loss: 2.0797 - accuracy: 0.4012
# Epoch 3/10
# 156836/156836 [==============================] - 167s 1ms/sample - loss: 1.4698 - accuracy: 0.5668
# Epoch 4/10
# 156836/156836 [==============================] - 166s 1ms/sample - loss: 1.1780 - accuracy: 0.6490
# Epoch 5/10
# 156836/156836 [==============================] - 166s 1ms/sample - loss: 0.9773 - accuracy: 0.7093
# Epoch 6/10
# 156836/156836 [==============================] - 156s 992us/sample - loss: 0.8319 - accuracy: 0.7525
# Epoch 7/10
# 156836/156836 [==============================] - 159s 1ms/sample - loss: 0.6988 - accuracy: 0.7927
# Epoch 8/10
# 156836/156836 [==============================] - 150s 955us/sample - loss: 0.5936 - accuracy: 0.8241
# Epoch 9/10
# 156836/156836 [==============================] - 148s 944us/sample - loss: 0.5091 - accuracy: 0.8488
# Epoch 10/10
# 156836/156836 [==============================] - 149s 948us/sample - loss: 0.4463 - accuracy: 0.8677
# 12630/12630 [==============================] - 6s 455us/sample - loss: 0.1877 - accuracy: 0.9519
#
#
# ==============================================================
#
#
# Loss 0.18770430593007345, Accuracy 0.9519398212432861
#
#
# ==============================================================

# %% [markdown]
# # Output Comments

# %% [markdown]
# After 10 epochs, the accuracy can reach nearly 97%. That is a not bad result. Compared with the non-extend training data, the mixed data seems like covers more features in and the accuracy difference between training set and test set is getting smaller. Also, we can clear see the loss is lower than it from non-extend set, which meaning the traffic sign variation is really happening in real world.
